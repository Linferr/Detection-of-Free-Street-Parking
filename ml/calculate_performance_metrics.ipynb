# %%
from ultralytics import YOLO

# %%
# Load our model
model = YOLO("./best.pt")

# %%
# Calculate performance metrics from test dataset
metrics = model.val(data='./data-def-full.yaml')
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.9.5 torch-2.1.1+cu118 CUDA:0 (NVIDIA GeForce RTX 2060 SUPER, 8192MiB)
# val: Scanning C:\Users\jdara\Documents\UBC\Year4\CPEN 491\MLFull\datasets\data\test\labels.cache... 491 images, 346 backgrounds, 0 corrupt: 100%|██████████| 491/491 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 31/31 [00:03<00:00,  8.70it/s]
#                    all        491        145      0.912      0.952      0.977      0.883
# Speed: 0.3ms preprocess, 1.7ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs\detect\val2

# %%
metrics
# Out:
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x000001AF8E0945B0>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# curves_results: [[array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
# ...

# %% [markdown]
# f1 = 2/((1/recall)+(1/precision)) = 2/((1/0.91235)+(1/0.951724)) = 0.93162

# %%
# Visualize model prediction on an image
path_to_image = "./datasets/data/test/images/IMG_8965_0051_1920x1080.png" # TODO: replace with path to your image
results = model(path_to_image)
# Out:
# image 1/1 c:\Users\jdara\Documents\UBC\Year4\CPEN 491\MLFull\datasets\data\test\images\IMG_8965_0051_1920x1080.png: 384x640 1 parking, 69.0ms
# Speed: 3.0ms preprocess, 69.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
from PIL import Image

# %%
# Show the image
im_array = results[0].plot() 
im = Image.fromarray(im_array[..., ::-1]) 
im
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>

# %%
im.save("result2.png")
